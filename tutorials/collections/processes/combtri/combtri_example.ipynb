# %% [markdown]
# # Datamine COMBTRI Process Example
#
# This notebook demonstrates how to configure and run the **`combtri`** process wrapper in `dmstudio`.
#
# ## Process Description
#
# ## COMBTRI
#
# Combines up to 20 pairs of wireframe model files, into a single pair of output files (a single wireframe).
#
# This process is similar to [ADDTRI](<addtri.md>), however that process is restricted to combining two wireframe pair files at a time.
#
# * **Note** (**COMBTRI** does not check for interpenetration of the two wireframes, but simply combines them into a single wireframe model.):
#
# ### Input Files:
#
# * **wiretr1** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr2** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr3** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr4** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr5** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr6** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr7** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr8** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr9** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr10** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr11** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr12** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr13** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr14** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr15** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr16** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr17** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr18** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr19** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wiretr20** (Wireframe Triangle):
#   Input wireframe triangle file 1 to 20
#   Required=Yes
#
# * **wirept1** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept2** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept3** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept4** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept5** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept6** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept7** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept8** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept9** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept10** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept11** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept12** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept13** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept14** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept15** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept16** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept17** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept18** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept19** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# * **wirept20** (Wireframe Points):
#   Input wireframe point file 1 to 20
#   Required=Yes
#
# ### Output Files:
#
# * **outtr** (Wireframe Triangle):
#   Output wireframe triangle file.
#   Required=Yes
#
# * **outpt** (Wireframe Points):
#   Output wireframe point file.
#   Required=No
#
# ### Fields:
#
# ### Parameters:

# %%
# Step 1: Connect to Datamine and Verify Active Project
import os
import shutil
import glob
import pandas as pd
from dmstudio import dmcommands, dmfiles, initialize, agent

# Connect to running Studio RM instance
dm_cmd = dmcommands.init(version='StudioRM')
dm_fil = dmfiles.init(version='StudioRM')
oScript = initialize.studio('StudioRM')
print(f"Connected to: {oScript.Caption}")

# Verify that the active project matches this folder (case-insensitive) to prevent writing files to the wrong place
active_folder = os.path.normpath(oScript.ActiveProject.Folder).lower()
notebook_folder = os.path.normpath(os.path.dirname(os.path.abspath('__file__'))).lower()

if active_folder != notebook_folder:
    raise RuntimeError(
        f"Active Datamine Project ({active_folder}) does not match this notebook's folder ({notebook_folder}).\n"
        "Please open the 'Project.rmproj' in this folder inside Datamine Studio RM first!"
    )
print("Active project verified successfully.")

# %% [markdown]
# ## Step 2: Introspect Schema
# Always inspect the parameter schema for the process wrapper to see the expected input and output files, fields, and parameters.

# %%
schema = agent.get_command_schema('combtri')
print(f"Process: {schema['name']}")
print("Parameters:")
for p in schema['parameters']:
    print(f"  - {p['name']}: default={p['default']}, annotation={p['annotation']}")

# %% [markdown]
# ## Step 3: Prepare Inputs
# We initialize the example project by copying the relevant standard datasets from the Datamine help database locally to this folder using a `t_` prefix. Paths are resolved relatively to ensure portability.

# %%
# Step 3: Initialize example project dataset using relative paths
# Resolve relative path to repository's help database dynamically (4 levels up from subfolders)
repo_root = os.path.abspath(os.path.join(notebook_folder, '..', '..', '..', '..'))
help_db = os.path.join(repo_root, 'datamine_help', 'Database', 'DMTutorials', 'Data', 'VBOP', 'Datamine')

files_to_copy = [
    "_vb_assays.dmx",
    "_vb_collars.dmx",
    "_vb_surveys.dmx",
    "_vb_lithology.dmx",
    "_vb_epar.dmx",
    "_vb_spar.dmx",
    "_vb_vpar.dmx",
    "_vb_mod1.dmx",
    "_vb_SurfacePointsPt.dmx",
    "_vb_SurfaceTriangles.dmx"
]

for filename in files_to_copy:
    src = os.path.join(help_db, filename)
    # Strip _vb_ prefix and prepend t_ for local usage
    local_name = "t_" + filename.replace("_vb_", "")
    dst = os.path.join(notebook_folder, local_name)
    if os.path.exists(src):
        shutil.copy(src, dst)
        print(f"Initialized dataset: {local_name}")
    else:
        print(f"Warning: Source {filename} not found in help database.")

# %% [markdown]
# ## Step 4: Execute Process
# Call the wrapper method with appropriate arguments. Below is the generated template execution call. Required parameters are active, and optional parameters are commented out.

# %%
# Execute combtri
print("Running combtri...")
dm_cmd.combtri(
    wiretrs_i=['t_SurfaceTriangles'],  # required
    wirepts_i=['t_SurfacePointsPt'],  # required
    outtr_o='t_combtri_out',  # required
    # outpt_o='t_combtri_out',  # optional
    # arguments='optional',  # optional
    # retrieval='optional',  # optional
)
print("combtri execution completed.")

# %% [markdown]
# ## Step 5: Verify Results
# Check that output files exist on disk and read them using pandas to verify the outputs.

# %%
# Step 5: Verify results
output_file = os.path.join(notebook_folder, 't_combtri_out.dmx')
if os.path.exists(output_file):
    df = agent.read_datamine(output_file)
    print(f"Output file loaded successfully. Rows: {len(df)}")
    print(df.head())
else:
    print("Output file not found (run Step 4 first)")

# %% [markdown]
# ## Step 6: Clean up Project Folder
# Always clean up generated temporary files to keep the directory clean.

# %%
# Step 6: Clean up temporary files and generated artifacts
# 1. Clean up temporary files matching t_*.*
temp_files = glob.glob(os.path.join(notebook_folder, "t_*.*"))
for f in temp_files:
    try:
        os.remove(f)
        print(f"Removed {os.path.basename(f)}")
    except Exception as e:
        print(f"Failed to remove {os.path.basename(f)}: {e}")

# 2. Clean up dynamic python initialization files (dmdir.py, __init__.py)
extra_files = ['dmdir.py', '__init__.py']
for f in extra_files:
    path = os.path.join(notebook_folder, f)
    if os.path.exists(path):
        try:
            os.remove(path)
            print(f"Removed {f}")
        except Exception as e:
            print(f"Failed to remove {f}: {e}")

# 3. Clean up cache directories (__pycache__)
pycache = os.path.join(notebook_folder, '__pycache__')
if os.path.exists(pycache):
    try:
        shutil.rmtree(pycache)
        print("Removed __pycache__")
    except Exception as e:
        print(f"Failed to remove __pycache__: {e}")
